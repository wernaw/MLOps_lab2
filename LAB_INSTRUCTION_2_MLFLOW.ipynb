# %% [markdown]
# # Laboratory 5 instruction part 2 - MLflow
#
# In machine learning development, one of the most challenging aspects is maintaining reproducibility. This issue is particularly relevant to the experimental phase, when a lot of small, but influential code changes are constantly introduced.
#
# After extensive experimentation with different model architectures, hyperparameters, and preprocessing techniques, researchers often find themselves unable to recreate their best-performing models because critical configuration details were not properly recorded.

# %% [markdown]
# ## MLflow
#
# [MLflow is an open-source platform](https://mlflow.org/) that addresses this challenge by providing systematic experiment tracking throughout the machine learning lifecycle. It automatically captures configurations, metrics, and artifacts from each model training run, transforming ad-hoc model development into a structured, reproducible process. In this notebook, we will learn how to use MLflow to properly track experiments for both traditional machine learning and deep learning workflows.

# %% [markdown]
# ### Laboratory plan
#
# 1. **MLflow tracking server** configuration and deployment for experiment management
# 2. **Automatic logging mechanisms** for scikit-learn experiments
# 3. **Manual logging implementation** for PyTorch deep learning workflows
# 4. **Hyperparameter optimization exercise** - systematic hyperparameter exploration
# 5. **Best practices** for experiment organization, versioning, and cross-team reproducibility

# %% [markdown]
# ## 1. MLflow Tracking server configuration
#
# [MLflow Tracking](https://mlflow.org/docs/latest/tracking/) is the main component of MLflow, responsible for capturing, storing, and presenting metrics, logs, and other tracking data. MLflow is based on a client-server architecture, where the central MLflow server can serve potentially whole teams of data scientists. You can also simply run it as a local server from the commandline, as we will now.
#
# You have two options for running MLflow:
#
# #### Option 1: Local MLflow (Simple)
# 1. Open terminal - we recommend to split it into 2 shells or just open additional session.
#
# 1. Create a directory for MLflow artifacts storage:
# ```bash
# mkdir mlflow-artifacts
# ```
#
# 2. Start the MLflow tracking server:
# ```bash
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./mlflow-artifacts \
#   --host 0.0.0.0 \
#   --port 5001
# ```
#
#
# **Important: Keep this terminal window open.** The MLflow server will continue running and be accessible at http://localhost:5001
#
# #### Option 2: MLflow with Docker (Recommended for production-like setup)
#
# 1. Create a `docker-compose.yml` file:
# ```yaml
# services:
#   mlflow:
#     image: ghcr.io/mlflow/mlflow:v2.9.2
#     container_name: mlflow-server
#     ports:
#       - "5001:5000"
#     volumes:
#       - ./mlflow-data:/mlflow
#     command:
#       - mlflow
#       - server
#       - --backend-store-uri
#       - sqlite:////mlflow/mlflow.db
#       - --default-artifact-root
#       - /mlflow/artifacts
#       - --host
#       - 0.0.0.0
#       - --port
#       - "5000"
#     restart: unless-stopped
# ```
#
# 2. Start MLflow with Docker:
# ```bash
# docker compose down -v
# rm -rf mlflow-data
# mkdir -p mlflow-data/artifacts
# docker compose up -d
# ```
#
# 3. Check if it's running:
# ```bash
# docker-compose ps
# ```
#
# 4. View logs (optional):
# ```bash
# docker-compose logs -f mlflow
# ```
#
# 5. To stop the server later:
# ```bash
# docker-compose down
# ```
#
# **Important: Add MLflow files to .gitignore**
#
# MLflow creates local files that should not be committed to Git. Add these lines to your `.gitignore`:
#
# ```
# # MLflow
# mlflow.db
# mlflow-artifacts/
# mlruns/
# ```
#
# These files contain experiment data and artifacts that are specific to your local machine. In production, you would use a remote tracking server and artifact storage (like S3).

# %%
from IPython.display import Image, display
display(Image(filename="image/MLflow_tracking_server_config.png"))

# %% [markdown]
# ### Connecting to MLflow
#
# To verify if the server runs properly, let's connect to it:
#
# ```python
# import mlflow
# import mlflow.sklearn
#
# import warnings
#
# warnings.filterwarnings("ignore")
#
# mlflow.set_tracking_uri("http://localhost:5001")
# print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# ```
#
# **To stop the MLflow server later:**
#
# - **Local setup**: Press `Ctrl+C` in the terminal where it's running
# - **Docker setup**: Run `docker-compose down`
#
# The server will shut down gracefully and save all your experiments.
#
# **Note:** Keep the server running throughout this lab session. All your experiments will be logged to this server instance.

# %%
import mlflow
import mlflow.sklearn

import warnings

warnings.filterwarnings("ignore")

mlflow.set_tracking_uri("http://localhost:5001")
print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# Out:
# Connected to MLflow at: http://localhost:5001

# %% [markdown]
# ## 2. Automatic logging with scikit-learn

# %% [markdown]
# ### 2.1 Dataset preparation
#
# In this section, we'll use the Ames Housing dataset to demonstrate MLflow's autologging capabilities with scikit-learn. Since we have already prepared the 2006-2008 data using DVC, we can use our preprocessed dataset here.

# %%
import numpy as np
import pandas as pd

from feature_engine.encoding import RareLabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
df = pd.read_parquet("data/ames_data_2006_2008.parquet")

df = df.sort_values(by=["YrSold"])

# As we have temporal data, the best way to evaluate our model is time (chronological) 
# split, where the newest data is used for testing. We will assume that we have the 
# data #for years 2006 and 2007, and evaluate using data from 2008.

df_train = df[df["YrSold"] < 2008]
df_test = df[df["YrSold"] == 2008]

y_train = df_train.pop("SalePrice")
y_test = df_test.pop("SalePrice")

categorical_features = df_train.select_dtypes(include="object").columns
numerical_features = df_train.select_dtypes(exclude="object").columns

# %%
median_imputer = SimpleImputer(strategy="median")
min_max_scaler = MinMaxScaler()
rare_encoder = RareLabelEncoder(tol=0.01, n_categories=0)
one_hot_encoder = OneHotEncoder(
    drop="first", sparse_output=False, handle_unknown="ignore"
)

num_pipeline = Pipeline(
    [("median_imputer", median_imputer), ("min_max_scaler", min_max_scaler)]
)

cat_pipeline = Pipeline(
    [("rare_encoder", rare_encoder), ("one_hot_encoder", one_hot_encoder)]
)

column_transformer = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_features),
        ("cat_pipeline", cat_pipeline, categorical_features),
    ],
    verbose_feature_names_out=False,
)
column_transformer.fit(df_train)

X_train = column_transformer.transform(df_train)
X_test = column_transformer.transform(df_test)

# %%
print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Number of features: {X_train.shape[1]}")
# Out:
# Training samples: 1312
# Test samples: 621
# Number of features: 181

# %% [markdown]
# ### 2.2 Training with MLflow autologging

# %% [markdown]
# Autologging is a powerful built-in capability of MLflow, enabling fully automated and near-zero code integration of MLflow with many popular frameworks. In particular, it works really well with scikit-learn, thanks to its highly unified API. Let's try this out - we will enable autologging, and then train a bunch of different models.

# %%
mlflow.sklearn.autolog(
    log_input_examples=True, log_model_signatures=True, log_models=False, silent=False
)

mlflow.set_experiment("ames-housing-autolog")
# Out:
# 2026/03/27 20:13:05 INFO mlflow.tracking.fluent: Experiment with name 'ames-housing-autolog' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/mlflow/artifacts/5', creation_time=1774638785185, experiment_id='5', last_update_time=1774638785185, lifecycle_stage='active', name='ames-housing-autolog', tags={}, workspace='default'>

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

models = [
    ("Ridge Regression", Ridge()),
    ("Decision Tree", DecisionTreeRegressor(max_depth=10, random_state=42)),
    ("K-Nearest Neighbors", KNeighborsRegressor(n_neighbors=10)),
    ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=100, random_state=42)),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score

def fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test):
    results = {}

    for model_name, model in models:
        # start MLflow run - a unit grouping logs from different model runs
        # everything within this context manager will get logged as a run
        with mlflow.start_run(run_name=model_name):
            model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()

            # log additional custom metrics, in addition to autologging
            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)
            mlflow.log_metric("rmse", rmse)
            mlflow.log_metric("mae", mae)

            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test)
# Out:
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# Ridge Regression:
#   RMSE: 23450.39
#   MAE: 16430.79
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.895 ± 0.035
# 🏃 View run Ridge Regression at: http://localhost:5001/#/experiments/5/runs/773ae4b753f74465833eb9938972cf3c
# 🧪 View experiment at: http://localhost:5001/#/experiments/5
#
# Decision Tree:
#   RMSE: 36860.51
#   MAE: 23270.66
#   R^2: 0.762
#   CV R^2 (mean ± std): 0.755 ± 0.057
# 🏃 View run Decision Tree at: http://localhost:5001/#/experiments/5/runs/6f269eeda51d47a5b6ffdd15abcfe526
# 🧪 View experiment at: http://localhost:5001/#/experiments/5
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:13 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# K-Nearest Neighbors:
#   RMSE: 38324.60
#   MAE: 26033.27
#   R^2: 0.743
#   CV R^2 (mean ± std): 0.691 ± 0.049
# 🏃 View run K-Nearest Neighbors at: http://localhost:5001/#/experiments/5/runs/bcdbecc16a6044a299ea6c8d7d756b56
# 🧪 View experiment at: http://localhost:5001/#/experiments/5
# 2026/03/27 20:13:14 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:15 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:15 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:15 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:16 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:16 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:17 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:17 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:18 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:18 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:18 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:19 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Random Forest:
#   RMSE: 25814.13
#   MAE: 15606.16
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.879 ± 0.049
# 🏃 View run Random Forest at: http://localhost:5001/#/experiments/5/runs/8613125c200c42028f97454b9714af56
# 🧪 View experiment at: http://localhost:5001/#/experiments/5
# 2026/03/27 20:13:19 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:19 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:19 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:19 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:20 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:20 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:20 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:20 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:20 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:20 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:21 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# Gradient Boosting:
#   RMSE: 21600.50
#   MAE: 13840.01
#   R^2: 0.918
#   CV R^2 (mean ± std): 0.904 ± 0.031
# 🏃 View run Gradient Boosting at: http://localhost:5001/#/experiments/5/runs/ea3ae7297d9e4a97adc6e3f5b7bdcab3
# 🧪 View experiment at: http://localhost:5001/#/experiments/5

# %% [markdown]
# Open the MLflow dashboard at http://localhost:5000/ and go to the Experiments tab. On the left, you have the experiment name, and when you select it, the list of all experiments will show up. Click through the interface and familiarize yourself with the most important elements:
#
# 1. What columns can be selected
# 2. Pick a particular run and check what values are logged automatically
# 3. Select columns to compare a given metric between runs, e.g. MAE
# 4. Sort algorithms by the selected metric to pick the best one

# %%
display(Image(filename="image/Training_with_MLflow_autologging.png"))

# %% [markdown]
# ## 2.3 Connecting DVC and MLflow
#
# You've already used DVC to version your dataset in the first part of this lab. Now let's connect DVC metadata with MLflow experiments to create a complete audit trail. When you run experiments, you want to know:
# - Which version of the data was used?
# - Can I reproduce these exact results?
# - What changed between experiments?
#
# By logging DVC metadata in MLflow, you create a link between your data versions and experiment results.

# %% [markdown]
# ### Reading DVC metadata
#
# DVC stores metadata in `.dvc` files. Let's read it:

# %%
import yaml

def get_dvc_metadata(dvc_file_path):
    with open(dvc_file_path, 'r') as f:
        dvc_data = yaml.safe_load(f)
    
    metadata = {
        'md5': dvc_data['outs'][0]['md5'],
        'size': dvc_data['outs'][0]['size'],
        'path': dvc_data['outs'][0]['path']
    }
    return metadata

dvc_metadata = get_dvc_metadata('data/ames_data_2006_2008.parquet.dvc')
print("DVC Metadata:")
print(f"MD5 hash: {dvc_metadata['md5']}")
print(f"File size: {dvc_metadata['size']} bytes")
print(f"Data path: {dvc_metadata['path']}")
# Out:
# DVC Metadata:
# MD5 hash: f44053333f88a0646819936b37f000ee
# File size: 162560 bytes
# Data path: ames_data_2006_2008.parquet

# %% [markdown]
# ### Exercise 1 - Logging DVC metadata in MLflow
#
# We have trained 5 different models. The results of all of them can now be compared in MLflow. Now let's modify our training to include DVC metadata. This creates a complete audit trail:
# - **Git commit** → tracks code version
# - **DVC hash** → tracks data version
# - **MLflow run** → tracks experiment results
#
# Your task is to:
# 1. Run 5 more experiments with different parameters and models from scikit-learn. You can use any [supervised learning methods from scikit-learn](https://scikit-learn.org/stable/supervised_learning.html). Find some other models or parameters to tune our current models with and run the experiments again.
# 2. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
# 3. Make sure you have included DVC metadata logging. You can initialize dvc_metadata by calling above defined `get_dvc_metadata` function with the .dvc metadata file. Then you can just for each experiment add param logging like:
#
# ```python
# mlflow.log_param("param_name", "value you want to log") # e.g md5
# ```

# %%
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet

models_new = [
    ("SVR RBF", SVR(C=10, epsilon=0.1, kernel="rbf")),
    ("AdaBoost", AdaBoostRegressor(n_estimators=300, learning_rate=0.05, random_state=42)),
    ("Lasso", Lasso(alpha=0.001, random_state=42)),
    ("ElasticNet", ElasticNet(alpha=0.001, l1_ratio=0.5, random_state=42)),
    ("SVR Linear", SVR(C=1.0, epsilon=0.2, kernel="linear")),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score

def fit_sklearn_models_with_cv_updated(models, X_train, X_test, y_train, y_test):
    results = {}

    dvc_metadata = get_dvc_metadata("data/ames_data_2006_2008.parquet.dvc")

    for model_name, model in models:
        with mlflow.start_run(run_name=model_name):
            model.fit(X_train, y_train)

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring="r2")
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)
            mlflow.log_metric("rmse", rmse)
            mlflow.log_metric("mae", mae)

            mlflow.log_param("MD5", dvc_metadata['md5'])
            mlflow.log_param("File size", dvc_metadata['size'])
            mlflow.log_param("Data path", dvc_metadata['path'])

            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv_updated(models_new, X_train, X_test, y_train, y_test)
# Out:
# 2026/03/27 20:13:52 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:52 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:52 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:52 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:53 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:53 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:53 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:53 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:53 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# SVR RBF:
#   RMSE: 77238.99
#   MAE: 54616.24
#   R^2: -0.044
#   CV R^2 (mean ± std): -0.095 ± 0.071
# 🏃 View run SVR RBF at: http://localhost:5001/#/experiments/5/runs/aa4bae98a60a400e969f3ae7528f2302
# 🧪 View experiment at: http://localhost:5001/#/experiments/5
# 2026/03/27 20:13:55 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:56 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:57 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:57 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:58 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:13:59 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:13:59 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# AdaBoost:
#   RMSE: 31695.10
#   MAE: 21699.18
#   R^2: 0.824
#   CV R^2 (mean ± std): 0.828 ± 0.060
# 🏃 View run AdaBoost at: http://localhost:5001/#/experiments/5/runs/4c909447c3e54d56a45349e616fd053f
# 🧪 View experiment at: http://localhost:5001/#/experiments/5
# 2026/03/27 20:14:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:00 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Lasso:
#   RMSE: 24117.64
#   MAE: 16792.71
#   R^2: 0.898
#   CV R^2 (mean ± std): 0.867 ± 0.074
# 🏃 View run Lasso at: http://localhost:5001/#/experiments/5/runs/334135ef7c504d9186a6f6ad593c1c3d
# 🧪 View experiment at: http://localhost:5001/#/experiments/5
# 2026/03/27 20:14:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# ElasticNet:
#   RMSE: 23555.30
#   MAE: 16475.74
#   R^2: 0.903
#   CV R^2 (mean ± std): 0.891 ± 0.039
# 🏃 View run ElasticNet at: http://localhost:5001/#/experiments/5/runs/042070112e034554854bee67ab7bf970
# 🧪 View experiment at: http://localhost:5001/#/experiments/5
# 2026/03/27 20:14:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# 2026/03/27 20:14:01 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/27 20:14:01 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: [Errno 30] Read-only file system: '/mlflow'
# SVR Linear:
#   RMSE: 76482.82
#   MAE: 53923.46
#   R^2: -0.024
#   CV R^2 (mean ± std): -0.079 ± 0.070
# 🏃 View run SVR Linear at: http://localhost:5001/#/experiments/5/runs/2d30da2459ce45ffa194664f5ed19831
# 🧪 View experiment at: http://localhost:5001/#/experiments/5

# %%
display(Image(filename="image/Exercise1_Logging_DVC_metadata_in_MLflow.png"))
display(Image(filename="image/Exercise1_Logging_DVC_metadata_in_MLflow_part2.png"))

# %% [markdown]
# ## 3. Manual logging with PyTorch
#
# In this section, we'll implement manual logging for PyTorch models. While scikit-learn has autologging, PyTorch requires manual tracking - giving us full control over what and when to log. MLflow supports autologging for [PyTorch Lightning](https://lightning.ai/docs/pytorch/stable/), but we often need low-level control of pure PyTorch.
#
# Note that we need to turn off scikit-learn autologging! Since we are using a Jupyter Notebook, MLflow uses the previously configured autologging unless explicitly turned off.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import KFold

# disable sklearn autologging!
mlflow.sklearn.autolog(disable=True)

mlflow.set_experiment("pytorch-housing-manual")
# Out:
# 2026/03/27 20:14:51 INFO mlflow.tracking.fluent: Experiment with name 'pytorch-housing-manual' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/mlflow/artifacts/6', creation_time=1774638891354, experiment_id='6', last_update_time=1774638891354, lifecycle_stage='active', name='pytorch-housing-manual', tags={}, workspace='default'>

# %% [markdown]
# ### 3.1 Targets transformation
#
# Before training the neural network, we will transform the training target, in order to stabilize the training. To see why, let's plot the house prices:

# %%
y_train.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Training on such targets is possible, but very large target values easily risk overflow, particularly when a loss function like mean squared error is used. We will use the log-transform to transform this distribution, as it's near-exponential, so it should bring it closer to normal, and also greatly reduce the values range.
#
# Of course, we will need to transform the network predictions back again to evaluate them.

# %%
y_train_log = np.log1p(y_train)

pd.Series(y_train_log).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 3.2 Define and train the model
#
# Since we have tabular data, we will use a simple 2-layer multilayer perceptron (MLP).

# %%
class HousePriceNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout_rate=0.2):
        super(HousePriceNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# For training, we will check both the 5-fold CV performance, and the traditional train-test split. Cross-validation will give us an additional, robust performance estimation, as well as standard deviation, which is useful for comparing performances of different models. After all, if the difference between models would be within one standard deviation, it wouldn't really be meaningful.

# %%
import torch.nn as nn


class PyTorchTrainer:
    def __init__(
        self, model_class: type[nn.Module], config: dict
    ):
        required_keys = ['hidden_units', 'dropout', 'batch_size', 'learning_rate', 
                         'log_interval', 'epochs', 'name']
        missing = [key for key in required_keys if key not in config]
        if missing:
            raise ValueError(f"Missing required config keys: {missing}")
        
        self.model_class = model_class
        self.config = config

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            hidden_dim=self.config["hidden_units"],
            dropout_rate=self.config["dropout"],
        )

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                metric_name = (
                    f"{metric_prefix}train_mse" if metric_prefix else "train_mse"
                )
                # manually log metric value, with a given name and step value
                mlflow.log_metric(metric_name, avg_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()
        
        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm.numpy())
        y_test = y_test.numpy()

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)

        return {"rmse": rmse, "mae": mae, "r2": r2}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                metric_prefix=f"fold_{fold + 1}_",
            )

            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val)
            
            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def _log_dvc_metadata(self, dvc_file_path: str = 'data/ames_data_2006_2008.parquet.dvc'):
        try:
            dvc_metadata = get_dvc_metadata(dvc_file_path)
            
            mlflow.log_param("data_dvc_md5", dvc_metadata['md5'])
            mlflow.log_param("data_dvc_size", dvc_metadata['size'])
            mlflow.log_param("data_path", dvc_metadata['path'])
            print(f"Logged DVC metadata: {dvc_metadata['md5'][:8]}...")
        except FileNotFoundError:
            print("DVC file not found - skipping metadata logging")
        except Exception as e:
            print(f"Could not log DVC metadata: {e}")

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)
            
            # Log DVC metadata for data versioning
            self._log_dvc_metadata()

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)
        
        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1))
        
        X_test_tensor = torch.FloatTensor(X_test)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1))

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")
        
        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor
    
    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %% [markdown]
# Quite a bit of code there! So now let's train the model.
#
# ### Configuration
# `base_config` contains **fixed parameters** that stay the same across all experiments:
# - `model_class`: The neural network architecture we're using (HousePriceNet)
# - `random_seed`: For reproducibility (42)
# - `log_interval`: How often to log metrics during training (every 5 epochs)
# - `num_samples`: Dataset size
# - `input_features`: Number of input features
# - `k_folds`: Number of cross-validation folds (5)
#
# `experiment_config` contains **hyperparameters** we want to tune:
# - `name`: Unique identifier for this experiment run
# - `hidden_units`: Size of the hidden layer (128, 256, 512, etc.)
# - `dropout`: Dropout rate for regularization (0.0 to 0.5)
# - `learning_rate`: Step size for gradient descent (0.001 to 0.1)
# - `epochs`: Number of training iterations (50, 100, 150, etc.)
# - `batch_size`: Number of samples per training batch (16, 32, 64, etc.)
#
# If you want you can deliver your own NeuralNetwork model, and just specify in experiment_config: `{"model_class": YourOwnModel}` it will overwrite the our base `HousePriceNet`

# %% [markdown]
# #### 3. Merging configurations
# We use Python's dictionary merge operator `|` to combine them:
# ```python
# training_config = base_config | experiment_config
# ```
#
# This creates a single configuration dictionary with all parameters. The `experiment_config` values override any duplicate keys from `base_config`, allowing us to easily experiment with different hyperparameters while keeping the base setup constant.
#
# Now let's set up our first experiment:

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

experiment_config = {
    "name": "first_run",
    "hidden_units": 128,
    "dropout": 0.1,
    "learning_rate": 0.03,
    "epochs": 150,
    "batch_size": 32,
}

# %%
training_config = base_config | experiment_config

trainer = PyTorchTrainer(training_config["model_class"], training_config)
trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for first_run...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 33412.20, MAE: 24189.24 R^2: 0.845
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 33357.45, MAE: 25463.67 R^2: 0.818
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 40690.17, MAE: 30617.78 R^2: 0.753
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 27708.47, MAE: 18198.29 R^2: 0.866
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 47358.20, MAE: 36914.77 R^2: 0.614
#
# Cross-validation complete. Mean R^2: 0.779 (+/- 0.091)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.779 (+/- 0.091)
#
# Cross-Validation Performance:
#   R^2: 0.877
#   RMSE: 26511.49
#   MAE: 18194.97
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run:
#
# ==================================================
# 🏃 View run first_run at: http://localhost:5001/#/experiments/6/runs/012cca27f2044bb5a7f815f47f9514e6
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# {'rmse': 26511.494140625,
#  'mae': 18194.97265625,
#  'r2': 0.8769867420196533,
#  'cv_r2_mean': np.float64(0.7791515588760376),
#  'cv_r2_std': np.float64(0.09090203883902101),
#  'cv_scores': [0.8453069925308228,
#   0.8176168203353882,
#   0.7533359527587891,
#   0.8656224012374878,
#   0.6138756275177002]}

# %% [markdown]
# ### Exercise 2
#
# Your task is to:
# 1. Run 10 experiments by modifying the hyperparameter configuration. Try to improve model performance, which is currently overfitted.
# 2. Analyze results in MLflow UI.
# 3. Comment on what changes impacted the model performance the most, and what changes disrupted the training process.
# 4. Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.
#
# **How to modify configurations:**
#
# You have two approaches:
#
# #### Approach 1: Loop through multiple configurations (Recommended for systematic exploration)
#
# Define a list of experiment configurations and iterate through them. Each configuration dictionary should contain only the hyperparameters you want to tune (name, hidden_units, dropout, learning_rate, epochs, batch_size). The base_config stays the same.
#
# ```python
# base_config = {
#     "model_class": HousePriceNet,
#     "random_seed": 42,
#     "log_interval": 5,
#     "input_features": X_train.shape[1],  # Number of features (181)
#     "num_samples": X_train.shape[0],     # Dataset size (1312)
#     "target_normalized": True,
#     "k_folds": 5,
# }
#
# # Define multiple experiments to run
# configs = [
#     {
#         "name": "baseline_128_units",
#         "hidden_units": 128,
#         "dropout": 0.1,
#         "learning_rate": 0.03,
#         "epochs": 150,
#         "batch_size": 32,
#     },
#     {
#         "name": "larger_network_256",
#         "hidden_units": 256,        # Try larger network
#         "dropout": 0.2,             # More dropout for regularization
#         "learning_rate": 0.01,      # Lower learning rate
#         "epochs": 200,
#         "batch_size": 64,
#     },
#     {
#         "name": "high_regularization",
#         "hidden_units": 128,
#         "dropout": 0.3,             # Even more dropout
#         "learning_rate": 0.01,
#         "epochs": 150,
#         "batch_size": 32,
#     },
#     # Add 7 more configurations here...
# ]
#
# # Run all experiments
# for experiment_config in configs:
#     training_config = base_config | experiment_config
#
#     trainer = PyTorchTrainer(training_config["model_class"], training_config)
#     results = trainer.fit(X_train, y_train_log, X_test, y_test)
# ```
#
# #### Approach 2: Manual and incremental (Good for quick iterations)
#
# Run experiments one by one, adjusting hyperparameters based on previous results:
#
# ```python
# # First experiment
# experiment_config = {
#     "name": "experiment_01_baseline",
#     "hidden_units": 128,
#     "dropout": 0.1,
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | experiment_config
# trainer = PyTorchTrainer(training_config["model_class"], training_config)
# results = trainer.fit(X_train, y_train_log, X_test, y_test)
# ```
# After analyzing results in MLflow, run another experiment
#
# ```
# experiment_config = {
#     "name": "experiment_02_more_dropout",
#     "hidden_units": 128,
#     "dropout": 0.3,  # Increased from 0.1
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | experiment_config
# trainer = PyTorchTrainer(training_config["model_class"], training_config)
# results = trainer.fit(X_train, y_train_log, X_test, y_test)
#
# # Continue with more experiments
# ```

# %% [markdown]
# **Tips for hyperparameter tuning:**
# - Start with one change at a time to understand its impact
# - Use meaningful experiment names that describe what you changed
# - Check MLflow UI after each experiment to guide your next choice
# - Look for signs of overfitting: high training performance but poor test performance
# - Watch the training curves in MLflow's "Model metrics" tab

# %% [markdown]
# ### Lab assessment
#
# Fill the code exercises in this Jupyter notebook, and send it with completed exercises, written comments in Markdown cells (particularly for questions in exercise 2), and screenshots of results in MLflow.

# %%
import torch.nn as nn


class PyTorchTrainer_updated:
    def __init__(
        self, model_class: type[nn.Module], config: dict
    ):
        required_keys = ['hidden_units', 'dropout', 'batch_size', 'learning_rate',
                         'log_interval', 'epochs', 'name']
        missing = [key for key in required_keys if key not in config]
        if missing:
            raise ValueError(f"Missing required config keys: {missing}")

        self.model_class = model_class
        self.config = config

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            hidden_dim=self.config["hidden_units"],
            dropout_rate=self.config["dropout"],
        )

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    @torch.no_grad()
    def eval_mse(self, model: nn.Module, loader: DataLoader) -> float:
        model.eval()
        criterion = nn.MSELoss()
        total = 0.0
        count = 0
        for Xb, yb in loader:
            preds = model(Xb)
            total += criterion(preds, yb).item()
            count += 1
        return total / count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        val_loader: DataLoader | None = None,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                base = f"{metric_prefix}" if metric_prefix else ""
                mlflow.log_metric(f"{base}train_mse", avg_mse, step=epoch)

                if val_loader is not None:
                    val_mse = self.eval_mse(model, val_loader)
                    mlflow.log_metric(f"{base}val_mse", val_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()

        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm.numpy())
        y_test = y_test.numpy()

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)

        return {"rmse": rmse, "mae": mae, "r2": r2}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)
            val_loader = self.create_data_loader(X_fold_val, y_fold_val, shuffle=False)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                val_loader=val_loader,
                metric_prefix=f"fold_{fold + 1}_",
            )
            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val)

            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def _log_dvc_metadata(self, dvc_file_path: str = 'data/ames_data_2006_2008.parquet.dvc'):
        try:
            dvc_metadata = get_dvc_metadata(dvc_file_path)

            mlflow.log_param("data_dvc_md5", dvc_metadata['md5'])
            mlflow.log_param("data_dvc_size", dvc_metadata['size'])
            mlflow.log_param("data_path", dvc_metadata['path'])
            print(f"Logged DVC metadata: {dvc_metadata['md5'][:8]}...")
        except FileNotFoundError:
            print("DVC file not found - skipping metadata logging")
        except Exception as e:
            print(f"Could not log DVC metadata: {e}")

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)

            # Log DVC metadata for data versioning
            self._log_dvc_metadata()

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)

        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1))

        X_test_tensor = torch.FloatTensor(X_test)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1))

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")

        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor

    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "input_features": X_train.shape[1],  # Number of features (181)
    "num_samples": X_train.shape[0],     # Dataset size (1312)
    "target_normalized": True,
    "k_folds": 5,
}

configs = [
    {
        "name": "baseline_128_units",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "larger_network_256",
        "hidden_units": 256,        # Try larger network
        "dropout": 0.2,             # More dropout for regularization
        "learning_rate": 0.01,      # Lower learning rate
        "epochs": 200,
        "batch_size": 64,
    },
    {
        "name": "high_regularization",
        "hidden_units": 128,
        "dropout": 0.3,             # Even more dropout
        "learning_rate": 0.01,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "hidden_64",
        "hidden_units": 64,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "hidden_256",
        "hidden_units": 256,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "dropout_0_2",
        "hidden_units": 128,
        "dropout": 0.2,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "dropout_0_3",
        "hidden_units": 128,
        "dropout": 0.3,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "lr_0_01",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.01,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "lr_0_005",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.005,
        "epochs": 150,
        "batch_size": 32,
    },
    {
        "name": "epochs_80",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 80,
        "batch_size": 32,
    },
    {
        "name": "epochs_200",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 200,
        "batch_size": 32,
    },
    {
        "name": "batch_64",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.03,
        "epochs": 200,
        "batch_size": 64,
    }
]

# %%
# Run all experiments
for experiment_config in configs:
    training_config = base_config | experiment_config

    trainer = PyTorchTrainer_updated(training_config["model_class"], training_config)
    results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for baseline_128_units...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 28505.82, MAE: 21687.17 R^2: 0.887
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 57411.68, MAE: 46708.74 R^2: 0.460
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 43979.31, MAE: 33170.53 R^2: 0.712
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 48254.82, MAE: 40664.05 R^2: 0.592
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 25002.12, MAE: 18011.09 R^2: 0.892
#
# Cross-validation complete. Mean R^2: 0.709 (+/- 0.168)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.709 (+/- 0.168)
#
# Cross-Validation Performance:
#   R^2: 0.764
#   RMSE: 36726.68
#   MAE: 26540.32
# Test Set Performance:
# ==================================================
# FINAL RESULTS for baseline_128_units:
#
# ==================================================
# 🏃 View run baseline_128_units at: http://localhost:5001/#/experiments/6/runs/0d0bd059feb847dc9640af069c2eb024
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for larger_network_256...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 63433.97, MAE: 46024.01 R^2: 0.442
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 61803.55, MAE: 50258.44 R^2: 0.374
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 40077.81, MAE: 30838.08 R^2: 0.761
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 54835.45, MAE: 32323.67 R^2: 0.474
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 45297.79, MAE: 34269.73 R^2: 0.647
#
# Cross-validation complete. Mean R^2: 0.540 (+/- 0.143)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.540 (+/- 0.143)
#
# Cross-Validation Performance:
#   R^2: 0.626
#   RMSE: 46221.61
#   MAE: 33496.21
# Test Set Performance:
# ==================================================
# FINAL RESULTS for larger_network_256:
#
# ==================================================
# 🏃 View run larger_network_256 at: http://localhost:5001/#/experiments/6/runs/6d5ba9beb43442fda1a73238265e1319
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for high_regularization...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 33502.84, MAE: 23970.24 R^2: 0.844
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 49683.00, MAE: 39195.74 R^2: 0.595
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 40551.82, MAE: 31336.08 R^2: 0.755
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 38065.42, MAE: 31094.07 R^2: 0.746
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 50555.88, MAE: 40698.90 R^2: 0.560
#
# Cross-validation complete. Mean R^2: 0.700 (+/- 0.106)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.700 (+/- 0.106)
#
# Cross-Validation Performance:
#   R^2: 0.893
#   RMSE: 24749.61
#   MAE: 16279.28
# Test Set Performance:
# ==================================================
# FINAL RESULTS for high_regularization:
#
# ==================================================
# 🏃 View run high_regularization at: http://localhost:5001/#/experiments/6/runs/f06df1fa4b21459b84968190866b3bdc
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for hidden_64...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 23442.78, MAE: 16178.17 R^2: 0.924
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 21649.27, MAE: 14906.73 R^2: 0.923
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 23418.25, MAE: 16320.54 R^2: 0.918
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 31602.84, MAE: 22537.20 R^2: 0.825
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 28916.61, MAE: 20652.04 R^2: 0.856
#
# Cross-validation complete. Mean R^2: 0.889 (+/- 0.041)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.889 (+/- 0.041)
#
# Cross-Validation Performance:
#   R^2: 0.904
#   RMSE: 23429.55
#   MAE: 15812.12
# Test Set Performance:
# ==================================================
# FINAL RESULTS for hidden_64:
#
# ==================================================
# 🏃 View run hidden_64 at: http://localhost:5001/#/experiments/6/runs/d615b13dce8745ea84775d06979305b3
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for hidden_256...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 45945.36, MAE: 37254.14 R^2: 0.707
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 62678.20, MAE: 49022.61 R^2: 0.356
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 54270.06, MAE: 40140.45 R^2: 0.561
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 52784.43, MAE: 35136.44 R^2: 0.512
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 44589.23, MAE: 33991.90 R^2: 0.658
#
# Cross-validation complete. Mean R^2: 0.559 (+/- 0.123)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.559 (+/- 0.123)
#
# Cross-Validation Performance:
#   R^2: 0.898
#   RMSE: 24153.03
#   MAE: 17929.55
# Test Set Performance:
# ==================================================
# FINAL RESULTS for hidden_256:
#
# ==================================================
# 🏃 View run hidden_256 at: http://localhost:5001/#/experiments/6/runs/4ceef67586c44d2daf827c9055ee9dee
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for dropout_0_2...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 23830.01, MAE: 15914.25 R^2: 0.921
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 29406.99, MAE: 20777.97 R^2: 0.858
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 26021.99, MAE: 18520.57 R^2: 0.899
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 24144.96, MAE: 15752.72 R^2: 0.898
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 23829.04, MAE: 16478.04 R^2: 0.902
#
# Cross-validation complete. Mean R^2: 0.896 (+/- 0.021)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.896 (+/- 0.021)
#
# Cross-Validation Performance:
#   R^2: 0.903
#   RMSE: 23584.04
#   MAE: 16450.94
# Test Set Performance:
# ==================================================
# FINAL RESULTS for dropout_0_2:
#
# ==================================================
# 🏃 View run dropout_0_2 at: http://localhost:5001/#/experiments/6/runs/7194ed6a171349fbb256afdbf69e89f2
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for dropout_0_3...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 24379.72, MAE: 16340.54 R^2: 0.918
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 27331.95, MAE: 20663.44 R^2: 0.878
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 23570.97, MAE: 15641.40 R^2: 0.917
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 31596.75, MAE: 21769.22 R^2: 0.825
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 23672.52, MAE: 16482.58 R^2: 0.904
#
# Cross-validation complete. Mean R^2: 0.888 (+/- 0.035)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.888 (+/- 0.035)
#
# Cross-Validation Performance:
#   R^2: 0.891
#   RMSE: 24979.05
#   MAE: 17739.61
# Test Set Performance:
# ==================================================
# FINAL RESULTS for dropout_0_3:
#
# ==================================================
# 🏃 View run dropout_0_3 at: http://localhost:5001/#/experiments/6/runs/491564c068d74603840f39f492aee44c
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for lr_0_01...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 64892.50, MAE: 48269.73 R^2: 0.416
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 58355.89, MAE: 39278.85 R^2: 0.442
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 42726.47, MAE: 30988.61 R^2: 0.728
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 47331.13, MAE: 35550.02 R^2: 0.608
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 35818.45, MAE: 25571.68 R^2: 0.779
#
# Cross-validation complete. Mean R^2: 0.595 (+/- 0.146)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.595 (+/- 0.146)
#
# Cross-Validation Performance:
#   R^2: 0.366
#   RMSE: 60194.63
#   MAE: 44924.70
# Test Set Performance:
# ==================================================
# FINAL RESULTS for lr_0_01:
#
# ==================================================
# 🏃 View run lr_0_01 at: http://localhost:5001/#/experiments/6/runs/e1ce4fcc47fc4dfdb747971ee19802c3
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for lr_0_005...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 36030.19, MAE: 27699.82 R^2: 0.820
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 76032.72, MAE: 53126.59 R^2: 0.052
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 47393.32, MAE: 34978.30 R^2: 0.665
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 71234.34, MAE: 50549.43 R^2: 0.112
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 43255.67, MAE: 31022.20 R^2: 0.678
#
# Cross-validation complete. Mean R^2: 0.466 (+/- 0.318)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.466 (+/- 0.318)
#
# Cross-Validation Performance:
#   R^2: 0.446
#   RMSE: 56251.53
#   MAE: 46457.62
# Test Set Performance:
# ==================================================
# FINAL RESULTS for lr_0_005:
#
# ==================================================
# 🏃 View run lr_0_005 at: http://localhost:5001/#/experiments/6/runs/45ca50315e954eb882ab5c36ef431bc6
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for epochs_80...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 57547.34, MAE: 43310.64 R^2: 0.541
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 128436.06, MAE: 92878.31 R^2: -1.704
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 91238.70, MAE: 74086.45 R^2: -0.240
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 67169.45, MAE: 51780.88 R^2: 0.210
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 69591.63, MAE: 59696.53 R^2: 0.166
#
# Cross-validation complete. Mean R^2: -0.205 (+/- 0.789)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: -0.205 (+/- 0.789)
#
# Cross-Validation Performance:
#   R^2: 0.207
#   RMSE: 67304.15
#   MAE: 48587.56
# Test Set Performance:
# ==================================================
# FINAL RESULTS for epochs_80:
#
# ==================================================
# 🏃 View run epochs_80 at: http://localhost:5001/#/experiments/6/runs/5ccd92aac9e54517b52889d81a2f107b
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for epochs_200...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 26154.22, MAE: 18774.53 R^2: 0.905
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 23420.84, MAE: 16848.43 R^2: 0.910
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 23856.47, MAE: 16492.39 R^2: 0.915
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 23871.53, MAE: 16318.65 R^2: 0.900
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 23729.37, MAE: 16124.77 R^2: 0.903
#
# Cross-validation complete. Mean R^2: 0.907 (+/- 0.005)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.907 (+/- 0.005)
#
# Cross-Validation Performance:
#   R^2: 0.481
#   RMSE: 54479.27
#   MAE: 37097.99
# Test Set Performance:
# ==================================================
# FINAL RESULTS for epochs_200:
#
# ==================================================
# 🏃 View run epochs_200 at: http://localhost:5001/#/experiments/6/runs/265853398fc04b13bbe8342e40e2cbfa
# 🧪 View experiment at: http://localhost:5001/#/experiments/6
# Training samples: 1312
# Input features: 181
# Logged DVC metadata: f4405333...
# Starting 5-fold cross-validation for batch_64...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 34535.70, MAE: 25141.38 R^2: 0.835
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 34541.30, MAE: 24067.35 R^2: 0.804
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 33731.77, MAE: 25272.94 R^2: 0.830
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 66777.34, MAE: 48629.34 R^2: 0.220
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 55602.39, MAE: 47654.46 R^2: 0.468
#
# Cross-validation complete. Mean R^2: 0.631 (+/- 0.248)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.631 (+/- 0.248)
#
# Cross-Validation Performance:
#   R^2: 0.870
#   RMSE: 27272.23
#   MAE: 18727.51
# Test Set Performance:
# ==================================================
# FINAL RESULTS for batch_64:
#
# ==================================================
# 🏃 View run batch_64 at: http://localhost:5001/#/experiments/6/runs/2f28dde8f85c4aeab64600a1f9e55a0c
# 🧪 View experiment at: http://localhost:5001/#/experiments/6

# %%
display(Image(filename="image/Exercise2_manual_logging_10experiments.png"))
display(Image(filename="image/Exercise2_manual_logging_first_run.png"))
display(Image(filename="image/scikit-learn_performance.png"))

# %% [markdown]
# ### Impact of hyperparameter changes on model performance
# - Increasing **dropout** can reduce overfitting, but too much leads to underfitting.
# - Lowering the **learning rate** often stabilizes training, but if it is too low, learning becomes very slow or may stall. Higher rates can be faster but unstable.
# - Reducing **hidden units** decreases model capacity and can reduce overfitting, but it also increases the risk of underfitting.
# - Reducing **epochs** can prevent overfitting, but it may also hurt final performance if the model has not converged.
#
# ### Comparison of scikit-learn and PyTorch
# **scikit‑learn**: Models such as Gradient Boosting or Random Forest showed good performance and decent generalization overall (based on cross-validation).
#
# **PyTorch**: The neural network achieved high training scores but noticeably lower validation/test scores, indicating overfitting and weaker generalization.
#
# ### Signs of overfitting in PyTorch
# - Training loss much lower than validation loss.
# - Test metrics worse than training metrics.
# - High variance in cross‑validation scores.
